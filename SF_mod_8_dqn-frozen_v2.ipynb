# %%
# !pip install -q tensorflow>=2.1

# %%
import numpy as np
import random

import gym

import tensorflow as tf
import tensorflow.keras.layers as L
import tensorflow.keras.models as M

import matplotlib.pyplot as plt
# %matplotlib inline
print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# ## Load GYM environment

# %%
env = gym.make('FrozenLake-v0', is_slippery=False)
s = env.reset()

NUM_STATES = env.observation_space.n
NUM_ACTIONS = env.action_space.n

print('States: {}'.format(NUM_STATES))
print('Actions: {}'.format(NUM_ACTIONS))
# Out:
# States: 16
# Actions: 4

# %% [markdown]
# ## Settings

# %%
LR = 0.1
gamma = 0.99

NUM_EPISODES = 2000
MAX_STEPS = 100
REWARD_AVERAGE_WINDOW = 20

# %% [markdown]
# ## DQN Model

# %%
model = M.Sequential([L.Dense(
    NUM_ACTIONS,
    activation=None,
    use_bias=False,
    kernel_initializer=tf.random_uniform_initializer(0, 0.01))])

def evalQ(s): #делаем инференсЖ как по некоторому состоянию s получить действие
     return model(tf.one_hot([s], NUM_STATES)).numpy()[0]

# %% [markdown]
# ## Prepare model for training

# %%
def loss(q1, q2):
    return tf.reduce_sum(tf.square(q1 - q2))

optimizer = tf.keras.optimizers.SGD(learning_rate=LR)
model.compile(loss=loss, optimizer=optimizer)

pathLenList = []
totalRewardList = []
totalRewardAverageList = []

# %% [markdown]
# ## DQN training

# %%
for i in range(NUM_EPISODES):
    
    eps = 1./((i/50) + 10)
    
    s = env.reset()
    
    totalReward = 0
    step = 0
    
    while step < MAX_STEPS:
        step += 1

        Q_s = evalQ(s)
        
        if np.random.rand() < eps:
            a = env.action_space.sample()
        else:
            a = np.argmax(Q_s)

        s1, r, done, _ = env.step(a)

        Q_s1 = evalQ(s1)
        
        Q_target = Q_s
        if done:
            Q_target[a] = r
        else:
            Q_target[a] = r + gamma * np.max(Q_s1)
        Q_target = tf.constant(Q_target)[None, ...]

        model.train_on_batch(tf.one_hot([s], NUM_STATES), Q_target)

        totalReward += r
        s = s1
        
        if done:
            break
            
    pathLenList.append(step)
    totalRewardList.append(totalReward)

    if i % REWARD_AVERAGE_WINDOW == 0 and i >= REWARD_AVERAGE_WINDOW:
        totalRewardAverage = np.mean(totalRewardList[-REWARD_AVERAGE_WINDOW:])
        totalRewardAverageList.append(totalRewardAverage)
        if i % 100 == 0:
            print('Episode {}: average total reward = {}'.format(i, totalRewardAverage))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f88e9e869d8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f88e9e869d8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     583     try:
# --> 584       if kwargs is not None:
#     585         result = converted_f(*effective_args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/conversion.py in convert(entity, program_ctx)
#     118
# --> 119   def has(self, entity, subkey):
#     120     key = self._get_key(entity)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/transpiler.py in transform_function(self, fn, caching_subkey, user_context, extra_locals)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/pyct/transpiler.py in instantiate(self, globals_, closure, defaults, kwdefaults)
#
# ValueError: closure mismatch, requested ('self', 'step_function'), but source function had ()
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-7b3a7b63eed3> in <module>()
#      29         Q_target = tf.constant(Q_target)[None, ...]
#      30
# ---> 31         model.train_on_batch(tf.one_hot([s], NUM_STATES), Q_target)
#      32
#      33         totalReward += r
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1693   def _in_multi_worker_mode(self):
#    1694     return self.distribute_strategy.extended._in_multi_worker_mode()  # pylint: disable=protected-access
# -> 1695
#    1696   def _get_distribution_strategy(self):
#    1697     return self.distribute_strategy
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778
#     779     Returns:
# --> 780       A `ConcreteFunction` object which initializes the variables of this
#     781       function.
#     782
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     821           self._stateless_fn._function_cache.all_values())
#     822     # pylint: enable=protected-access
# --> 823     seen_signatures = []
#     824     for concrete_function in concrete_functions:
#     825       signature = concrete_function.structured_input_signature
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     695       # We want to call stateless_fn if possible because it avoids recomputing
#     696       # potentially expensive initializers.
# --> 697       return control_flow_ops.cond(
#     698           condition,
#     699           lambda: self._stateless_fn(*inner_args, **inner_kwds),
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2853   present in its corresponding graph), but it is not yet possible to execute the
#    2854   generated graphs across multiple machines.
# -> 2855
#    2856   _Example Usage_
#    2857
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3211             autograph=autograph,
#    3212             autograph_options=experimental_autograph_options,
# -> 3213             experimental_compile=experimental_compile,
#    3214             experimental_relax_shapes=experimental_relax_shapes))
#    3215
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3073   TensorFlow APIs, like `tf.keras.layers.Layer` objects, create variables the
#    3074   first time they are called and reuse them thereafter. Automatic variable
# -> 3075   lifting makes it possible to compile these APIs without extra effort, at the
#    3076   cost of introducing a discrepancy between the semantics of executing Python
#    3077   functions and their corresponding compiled functions. For example:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984       # TensorArrays and `None`s.
#     985       func_outputs = nest.map_structure(convert, func_outputs,
# --> 986                                         expand_composites=True)
#     987
#     988       check_mutation(func_args_before, func_args, original_func)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     598                             self._python_function))
#     599
# --> 600     return result
#     601
#     602   def _call(self, *args, **kwds):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     967             if hasattr(e, "ag_error_metadata"):
#     968               raise e.ag_error_metadata.to_exception(e)
# --> 969             else:
#     970               raise
#     971
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     589       _attach_metadata(e, converted_f)
#     590       raise
# --> 591
#     592   return result
#     593
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py in _fall_back_unconverted(f, args, kwargs, options, exc)
#     396     args: Tuple, the original positional arguments of f
#     397     kwargs: Optional[Dict], the original keyword arguments of f
# --> 398     caller_fn_scope: Optional[function_wrappers.FunctionScope], the function
#     399       scope of the converted function in which this call was originally made.
#     400     options: Optional[converter.ConversionOptions], conversion options. If not
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     337 def _call_unconverted(f, args, kwargs, options, update_cache=True):
#     338   """Calls the original function without converting with AutoGraph."""
# --> 339   if update_cache:
#     340     conversion.cache_whitelisted(f, options)
#     341
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in train_function(iterator)
#     804           y=y,
#     805           sample_weight=sample_weight,
# --> 806           batch_size=batch_size,
#     807           steps_per_epoch=steps_per_epoch,
#     808           initial_epoch=initial_epoch,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in step_function(model, iterator)
#     794       (x, y, sample_weight), validation_data = (
#     795           data_adapter.train_validation_split((x, y, sample_weight),
# --> 796                                               validation_split=validation_split,
#     797                                               shuffle=False))
#     798
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1209     `tensor` will be be split among multiple logical devices. Tensor `tensor`
#    1210     will be split across dimensions specified by `partition_dimensions`.
# -> 1211     The dimensions of `tensor` must be divisible by corresponding value in
#    1212     `partition_dimensions`.
#    1213
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2583       except RuntimeError as e:
#    2584         six.raise_from(
# -> 2585             RuntimeError("Variable creator scope nesting error: move call to "
#    2586                          "tf.distribute.set_strategy() out of `with` scope."),
#    2587             e)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     253
#     254     def wrapper(*args, **kwargs):
# --> 255       """Wrapper that calls the converted version of f."""
#     256       options = converter.ConversionOptions(
#     257           recursive=recursive,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     530             target_entity.__code__.co_filename == '<string>'):
#     531         # TODO(mdan): __globals__['txt'] might work in Py3.
# --> 532         logging.log(2, 'Permanently whitelisted: %s: dynamic code (exec?)',
#     533                     target_entity)
#     534         return _call_unconverted(f, args, kwargs, options)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     337 def _call_unconverted(f, args, kwargs, options, update_cache=True):
#     338   """Calls the original function without converting with AutoGraph."""
# --> 339   if update_cache:
#     340     conversion.cache_whitelisted(f, options)
#     341
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in run_step(data)
#     787     version_utils.disallow_legacy_graph('Model', 'fit')
#     788     self._assert_compile_was_called()
# --> 789     self._check_call_args('fit')
#     790
#     791     if validation_split:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in train_step(self, data)
#     755       iterator should return a tuple of length 1, 2, or 3, where the optional
#     756       second and third elements will be used for y and sample_weight
# --> 757       respectively. Any other type provided will be wrapped in a length one
#     758       tuple, effectively treating everything as 'x'. When yielding dicts, they
#     759       should still adhere to the top-level tuple structure.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _minimize(strategy, tape, optimizer, loss, trainable_variables)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1040                           for x in nest.flatten(output_gradients)]
#    1041
# -> 1042     flat_grad = imperative_grad.imperative_grad(
#    1043         self._tape,
#    1044         flat_targets,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/lazy_loader.py in __getattr__(self, item)
#      60
#      61   def __getattr__(self, item):
# ---> 62     module = self._load()
#      63     return getattr(module, item)
#      64
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/lazy_loader.py in _load(self)
#      43     """Load the module and insert it into the parent's globals."""
#      44     # Import the target module and insert it into the parent's namespace
# ---> 45     module = importlib.import_module(self.__name__)
#      46     self._parent_module_globals[self._local_name] = module
#      47
#
# /usr/lib/python3.6/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'tensorflow.python.ops.numpy_ops'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Plot trajectory length over time

# %%
plt.plot(pathLenList)
plt.grid()

# %% [markdown]
# ## Plot average total reward over time

# %%
plt.plot(totalRewardAverageList)
plt.grid()

# %% [markdown]
# ## Run simulation

# %%
s = env.reset()

for _ in range(1000):
    env.render()
    a = np.argmax(evalQ(s))
    s, r, done, _ = env.step(a)
    if done:
        env.render()
        print('Reward = {}'.format(r))
        break
        
env.close()
